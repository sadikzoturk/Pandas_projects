# %% [markdown]
# # Business Problem

# %% [markdown]
# **Birliktelik Kuralları Nedir?**
#
# Veri içerisindeki pattern'leri (ilişkileri, yapıları) bulmak için kullanılan kural tabanlı bir makine öğrenmesi tekniğidir.
#
#
# Birliktelik analizi uygulamaları veri biliminde en çok karşımıza çıkan uygulamalardandır. Tavsiye sistemleri olarak da denk gelmiş olacaktır.
#
#
# Bu uygulamalar karşınıza şu şekillerde gelmiş olabilir "o ürünü alan bu ürünü de aldı" ya da "o ilana bakanlar bu ilanlara da baktı" ya da "senin için çalma listesi oluşturduk" ya da "sıradaki video için önerilen video" gibi.
#
# Bu senaryolar e-ticaret veri bilimi veri madenciliği çalışmaları kapsamında en sık karşımıza çıkacak olan senaryolar.
#
# Türkiye'deki ve dünyadaki büyük e-ticaret şirketleri, spotify, amazon, netflix gibi biraz daha yakından bilebileceğimiz birçok platform tavsiye sistemlerini kullanmaktadır.
#
# Peki özetle ne yapmaktadır bu birliktelik analizleri?
#
#
# **Apriori Algoritması**
#
# Bu alanda en çok kullanılan yöntemdir.
#
# Birliktelik kuralı analizi bazı metrikler incelenerek gerçekleştirilir:
#
# - Destek (Support)
#
# Support(X, Y) = Freq(X,Y)/N
#
# X: ürün
# Y: ürün
# N: toplam alışveriş
#
# - Güven (Confidence)
#
# Confidence(X, Y) = Freq(X,Y) / Freq(X)
#
# - Lift
#
# Lift = Support (X, Y) / ( Support(X) * Support(Y) )

# %% [markdown]
# # Data Understanding

# %%
#!pip install mlxtend

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv('GroceryStoreDataSet.csv', sep=',',header=None)
data = list(df[0].apply(lambda x:x.split(',')))

# %%
items=[]
for row in data:
    uncommons = list(set(row) -set(items))
    for uc in uncommons:
        items.append(uc)
items
# Out:
# ['MILK',
#  'BREAD',
#  'BISCUIT',
#  'CORNFLAKES',
#  'TEA',
#  'BOURNVITA',
#  'MAGGI',
#  'JAM',
#  'COFFEE',
#  'COCK',
#  'SUGER']

# %%
df=pd.DataFrame(data)

# %%
encoded_vals = []
for index, row in df.iterrows(): 
    labels = {}
    uncommons = list(set(items) - set(row))
    commons = list(set(items).intersection(row))
    for uc in uncommons:
        labels[uc] = 0
    for com in commons:
        labels[com] = 1
    encoded_vals.append(labels)
type(encoded_vals)
# Out:
# list

# %%
df=pd.DataFrame(encoded_vals)

# %% [markdown]
# from mlxtend.preprocessing import TransactionEncoder
#
# te = TransactionEncoder()
# te_data = te.fit(data).transform(data)

# %% [markdown]
# x=pd.DataFrame(te_data)

# %% [markdown]
# x.head()

# %%
freq_items = apriori(df, min_support = 0.10, use_colnames = True, verbose = 1)
# Out:
# Processing 40 combinations | Sampling itemset size 4

# %%
freq_items.head()
# Out:
#    support      itemsets
# 0     0.40      (COFFEE)
# 1     0.30  (CORNFLAKES)
# 2     0.25       (MAGGI)
# 3     0.20   (BOURNVITA)
# 4     0.15        (COCK)

# %%
ar=association_rules(freq_items, metric = "confidence", min_threshold = 0.8)
ar
# Out:
#                       antecedents           consequents  antecedent support  \
# 0                          (COCK)              (COFFEE)                0.15
# 1                           (JAM)               (MAGGI)                0.10
# 2                         (MAGGI)                 (TEA)                0.25
# 3                           (JAM)               (BREAD)                0.10
# 4                          (MILK)               (BREAD)                0.25
# 5              (CORNFLAKES, COCK)              (COFFEE)                0.10
# 6               (COFFEE, BISCUIT)          (CORNFLAKES)                0.10
# 7               (COFFEE, BISCUIT)                (COCK)                0.10
# 8                 (BISCUIT, COCK)              (COFFEE)                0.10
# 9              (CORNFLAKES, COCK)             (BISCUIT)                0.10
# 10                (BISCUIT, COCK)          (CORNFLAKES)                0.10
# 11                   (BREAD, JAM)               (MAGGI)                0.10
# 12                   (MAGGI, JAM)               (BREAD)                0.10
# 13                          (JAM)        (BREAD, MAGGI)                0.10
# 14               (MAGGI, BISCUIT)                 (TEA)                0.10
# 15                 (TEA, BISCUIT)               (MAGGI)                0.10
# 16               (BOURNVITA, TEA)               (BREAD)                0.10
# 17                (MILK, BISCUIT)               (BREAD)                0.10
# 18     (COFFEE, CORNFLAKES, COCK)             (BISCUIT)                0.10
# 19        (COFFEE, BISCUIT, COCK)          (CORNFLAKES)                0.10
# 20  (COFFEE, CORNFLAKES, BISCUIT)                (COCK)                0.10
# 21    (CORNFLAKES, BISCUIT, COCK)              (COFFEE)                0.10
# 22              (COFFEE, BISCUIT)    (CORNFLAKES, COCK)                0.10
# 23             (CORNFLAKES, COCK)     (COFFEE, BISCUIT)                0.10
# 24                (BISCUIT, COCK)  (COFFEE, CORNFLAKES)                0.10
#
#     consequent support  support  confidence       lift  leverage  conviction
# 0                 0.40     0.15         1.0   2.500000    0.0900         inf
# 1                 0.25     0.10         1.0   4.000000    0.0750         inf
# 2                 0.35     0.20         0.8   2.285714    0.1125        3.25
# 3                 0.65     0.10         1.0   1.538462    0.0350         inf
# 4                 0.65     0.20         0.8   1.230769    0.0375        1.75
# 5                 0.40     0.10         1.0   2.500000    0.0600         inf
# 6                 0.30     0.10         1.0   3.333333    0.0700         inf
# 7                 0.15     0.10         1.0   6.666667    0.0850         inf
# 8                 0.40     0.10         1.0   2.500000    0.0600         inf
# 9                 0.35     0.10         1.0   2.857143    0.0650         inf
# 10                0.30     0.10         1.0   3.333333    0.0700         inf
# 11                0.25     0.10         1.0   4.000000    0.0750         inf
# 12                0.65     0.10         1.0   1.538462    0.0350         inf
# 13                0.15     0.10         1.0   6.666667    0.0850         inf
# 14                0.35     0.10         1.0   2.857143    0.0650         inf
# 15                0.25     0.10         1.0   4.000000    0.0750         inf
# 16                0.65     0.10         1.0   1.538462    0.0350         inf
# 17                0.65     0.10         1.0   1.538462    0.0350         inf
# 18                0.35     0.10         1.0   2.857143    0.0650         inf
# 19                0.30     0.10         1.0   3.333333    0.0700         inf
# 20                0.15     0.10         1.0   6.666667    0.0850         inf
# 21                0.40     0.10         1.0   2.500000    0.0600         inf
# 22                0.10     0.10         1.0  10.000000    0.0900         inf
# 23                0.10     0.10         1.0  10.000000    0.0900         inf
# 24                0.20     0.10         1.0   5.000000    0.0800         inf

# %%
ar[(ar.support>0.1)  &  (ar.confidence > 0.8) ]
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0      (COCK)    (COFFEE)                0.15                 0.4     0.15
#
#    confidence  lift  leverage  conviction
# 0         1.0   2.5      0.09         inf

# %%
ar
